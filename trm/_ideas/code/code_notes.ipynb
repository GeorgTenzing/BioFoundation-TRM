# %% [markdown]
# ## Notes on Code

# %% [markdown]
# ### BioFoundation / EEG_Classification
#
#
# BioFoundation/
# ├── config                   # Hydra configuration files
# ├── criterion                # Loss functions
# ├── data_module              # PyTorch Lightning DataModules = (training.core.)data_loading.load_dataset
# ├── datasets                 # PyTorch Datasets              = (data.datasets.)eeg_dataset.EEGDatasetWithFilters
# ├── docs                     # Detailed documentation
# ├── models                   # Model implementations
# ├── schedulers               # Learning rate schedulers
# ├── tasks                    # PyTorch Lightning tasks       = (models.)basemodel.BaseModel
# └── ...

# %% [markdown]
# ## Notes on Datasets

# %% [markdown]
# ### NON-Biosignal:
#
# #### UCR / UEA
#
#
# #### UCI

# %% [markdown]
# ### Biosignal:
#
# #### BCI Competition
